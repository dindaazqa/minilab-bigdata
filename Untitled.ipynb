# %%
import sqlalchemy
from sqlalchemy import create_engine, text


engine = create_engine('postgresql://admin:admin123@localhost:5432/minilab_db')

setup_sql = """
CREATE TABLE IF NOT EXISTS customers (
    customer_id   INT PRIMARY KEY,
    customer_name VARCHAR(100),
    city          VARCHAR(100),
    age           INT,
    signup_date   DATE
);

INSERT INTO customers VALUES
(1, 'Adit', 'Surabaya', 27, '2023-10-12'),
(2, 'Bunga', 'Malang', 23, '2023-11-03'),
(3, 'Cahyo', 'Jakarta', 36, '2024-01-08'),
(4, 'Dewi', 'Bandung', 25, '2024-02-20'),
(5, 'Eko', 'Yogyakarta', 32, '2023-09-15'),
(6, 'Fina', 'Semarang', 28, '2024-03-05'),
(7, 'Galih', 'Medan', 41, '2023-08-21'),
(8, 'Hana', 'Makassar', 30, '2024-01-30'),
(9, 'Iqbal', 'Denpasar', 26, '2024-02-18'),
(10, 'Joko', 'Balikpapan', 24, '2024-04-01'),
(11, 'Kiki', 'Surabaya', 22, '2024-01-12'),
(12, 'Lina', 'Jakarta', 34, '2023-12-10'),
(13, 'Maman', 'Bandung', 29, '2024-03-18'),
(14, 'Nina', 'Malang', 31, '2023-11-20'),
(15, 'Omar', 'Yogyakarta', 37, '2024-04-10'),
(16, 'Putri', 'Kediri', 21, '2024-02-08'),
(17, 'Rizky', 'Blitar', 43, '2023-07-30'),
(18, 'Salsa', 'Surabaya', 27, '2024-01-03'),
(19, 'Tari', 'Jakarta', 28, '2024-03-25'),
(20, 'Umar', 'Malang', 35, '2023-10-05')
ON CONFLICT (customer_id) DO NOTHING;

CREATE TABLE IF NOT EXISTS products (
    product_id   INT PRIMARY KEY,
    product_name VARCHAR(150),
    category     VARCHAR(100),
    price        INT,
    stock        INT
);

INSERT INTO products VALUES
(1, 'Laptop Ultrabook 14"', 'Elektronik', 12000000, 8),
(2, 'Keyboard Mechanical RGB', 'Elektronik', 850000, 20),
(3, 'Mouse Wireless Gaming', 'Elektronik', 450000, 35),
(4, 'Smart LED Bulb', 'Smart Home', 120000, 50),
(5, 'Smart Plug WiFi', 'Smart Home', 180000, 40),
(6, 'CCTV Indoor Camera', 'Smart Home', 650000, 15),
(7, 'Carrier Backpack 60L', 'Outdoor', 950000, 12),
(8, 'Matras Camping', 'Outdoor', 150000, 45),
(9, 'Lampu Tenda LED', 'Outdoor', 80000, 60),
(10, 'Blender Multifungsi', 'Dapur', 700000, 18),
(11, 'Rice Cooker 1.8L', 'Dapur', 500000, 25),
(12, 'Panci Set Stainless', 'Dapur', 600000, 30)
ON CONFLICT (product_id) DO NOTHING;

CREATE TABLE IF NOT EXISTS orders (
    order_id    INT PRIMARY KEY,
    customer_id INT REFERENCES customers(customer_id),
    product_id  INT REFERENCES products(product_id),
    quantity    INT,
    order_date  DATE
);

INSERT INTO orders VALUES
(1,1,1,1,'2024-01-15'),
(2,1,2,1,'2024-01-15'),
(3,2,4,2,'2024-01-18'),
(4,3,10,1,'2024-02-10'),
(5,3,11,1,'2024-02-10'),
(6,4,4,1,'2024-03-01'),
(7,4,5,1,'2024-03-01'),
(8,5,7,1,'2023-11-20'),
(9,5,8,1,'2023-11-20'),
(10,6,2,1,'2024-03-08'),
(11,7,6,1,'2023-10-10'),
(12,8,5,1,'2024-02-05'),
(13,9,8,2,'2024-03-03'),
(14,10,3,1,'2024-04-02'),
(15,11,1,1,'2024-02-01'),
(16,12,10,1,'2024-01-07'),
(17,13,3,1,'2024-03-20'),
(18,14,7,1,'2024-01-18'),
(19,15,9,1,'2024-04-15'),
(20,16,12,1,'2024-02-22'),
(21,17,11,2,'2023-09-05'),
(22,18,4,1,'2024-02-18'),
(23,19,1,1,'2024-04-03'),
(24,20,10,1,'2023-11-28')
ON CONFLICT (order_id) DO NOTHING;
"""

with engine.connect() as conn:
    conn.execute(text(setup_sql))
    conn.commit()

print("✅ Database Inisialisasi Berhasil!")
# Out:
# ✅ Database Inisialisasi Berhasil!

# %%
import pandas as pd


# Dataset Products (UPDATED)
df_products = pd.DataFrame({
    'product_id': range(1, 13),
    'product_name': [
        'Laptop Ultrabook 14"', 'Keyboard Mechanical RGB', 'Mouse Wireless Gaming',
        'Smart LED Bulb', 'Smart Plug WiFi', 'CCTV Indoor Camera',
        'Carrier Backpack 60L', 'Matras Camping', 'Lampu Tenda LED',
        'Blender Multifungsi', 'Rice Cooker 1.8L', 'Panci Set Stainless'
    ],
    'category': [
        'Elektronik', 'Elektronik', 'Elektronik',
        'Smart Home', 'Smart Home', 'Smart Home',
        'Outdoor', 'Outdoor', 'Outdoor',
        'Dapur', 'Dapur', 'Dapur'
    ],
    'price': [
        12000000, 850000, 450000,
        120000, 180000, 650000,
        950000, 150000, 80000,
        700000, 500000, 600000
    ],
    'stock': [
        8, 20, 35,
        50, 40, 15,
        12, 45, 60,
        18, 25, 30
    ]
})

# Simpan ke CSV
df_products.to_csv('products.csv', index=False)

print("✅ CSV berhasil dibuat!")
# Out:
# ✅ CSV berhasil dibuat!

# %%
import pandas as pd

# 1. Definisikan data (UPDATED)
data_orders = [
    (1,1,1,1,'2024-01-15'),
    (2,1,2,1,'2024-01-15'),
    (3,2,4,2,'2024-01-18'),
    (4,3,10,1,'2024-02-10'),
    (5,3,11,1,'2024-02-10'),
    (6,4,4,1,'2024-03-01'),
    (7,4,5,1,'2024-03-01'),
    (8,5,7,1,'2023-11-20'),
    (9,5,8,1,'2023-11-20'),
    (10,6,2,1,'2024-03-08'),
    (11,7,6,1,'2023-10-10'),
    (12,8,5,1,'2024-02-05'),
    (13,9,8,2,'2024-03-03'),
    (14,10,3,1,'2024-04-02'),
    (15,11,1,1,'2024-02-01'),
    (16,12,10,1,'2024-01-07'),
    (17,13,3,1,'2024-03-20'),
    (18,14,7,1,'2024-01-18'),
    (19,15,9,1,'2024-04-15'),
    (20,16,12,1,'2024-02-22'),
    (21,17,11,2,'2023-09-05'),
    (22,18,4,1,'2024-02-18'),
    (23,19,1,1,'2024-04-03'),
    (24,20,10,1,'2023-11-28')
]

df_orders = pd.DataFrame(
    data_orders,
    columns=['order_id', 'customer_id', 'product_id', 'quantity', 'order_date']
)

# 3. Export ke Excel
df_orders.to_excel('orders_source.xlsx', index=False)

print("✅ File 'orders_source.xlsx' berhasil dibuat!")

df_orders.head()
# Out:
# ✅ File 'orders_source.xlsx' berhasil dibuat!
#    order_id  customer_id  product_id  quantity  order_date
# 0         1            1           1         1  2024-01-15
# 1         2            1           2         1  2024-01-15
# 2         3            2           4         2  2024-01-18
# 3         4            3          10         1  2024-02-10
# 4         5            3          11         1  2024-02-10

# %%
from minio import Minio
from minio.error import S3Error
import pandas as pd
import sqlalchemy
import io


client = Minio(
    "localhost:9000",
    access_key="minioadmin", 
    secret_key="minioadmin123", 
    secure=False
)

# Buat bucket kalau belum ada
bucket = "minilab-datalake"
if not client.bucket_exists(bucket):
    client.make_bucket(bucket)
    print(f"✅ Bucket '{bucket}' berhasil dibuat!")
else:
    print(f"✅ Bucket '{bucket}' sudah ada!")

# Fungsi upload DataFrame ke MinIO
def upload_to_minio(df, path):
    csv_bytes = df.to_csv(index=False).encode('utf-8')
    client.put_object(
        bucket,
        path,
        data=io.BytesIO(csv_bytes),
        length=len(csv_bytes),
        content_type="text/csv"
    )
    print(f"🚀 Berhasil upload ke: {path} ({len(df)} baris)")

# 2. Koneksi PostgreSQL
engine = sqlalchemy.create_engine('postgresql://admin:admin123@localhost:5432/minilab_db')

# --- BAGIAN A: Ingestion dari RDBMS ---
print("\n--- Processing RDBMS Data ---")
# Menarik data dari tabel E-Commerce Anda
df_customers = pd.read_sql("SELECT * FROM customers", engine)
df_products  = pd.read_sql("SELECT * FROM products", engine)
df_orders_db = pd.read_sql("SELECT * FROM orders", engine)

upload_to_minio(df_customers, "raw/rdbms/customersrdbms.csv")
upload_to_minio(df_products,  "raw/rdbms/productsrdbms.csv")
upload_to_minio(df_orders_db, "raw/rdbms/ordersrdbms.csv")

# --- BAGIAN B: Ingestion dari File Lokal (Dataset Berbeda) ---
print("\n--- Processing File Data ---")

# 1. Ingestion dari CSV (Menggunakan file orders_source.csv yang baru Anda buat)
try:
    df_csv = pd.read_csv("products.csv")
    upload_to_minio(df_csv, "raw/csv/products.csv")
except FileNotFoundError:
    print("❌ Error: File 'products.csv' tidak ditemukan!")

# 2. Ingestion dari XLSX (Opsional: Jika Anda punya file excel lain)
# Jika belum ada file .xlsx, Anda bisa skip bagian ini atau buat dummy singkat
try:
    df_xlsx = pd.read_excel("orders_source.xlsx") # Ganti nama file jika ada
    upload_to_minio(df_xlsx, "raw/xlsx/orders.csv")
except Exception as e:
    print(f"⚠️ Ingestion XLSX dilewati karena: {e}")

print("\n🎉 Semua data berhasil di-ingestion ke MinIO!")
# Out:
# ✅ Bucket 'minilab-datalake' sudah ada!
#
# --- Processing RDBMS Data ---
# 🚀 Berhasil upload ke: raw/rdbms/customersrdbms.csv (20 baris)
# 🚀 Berhasil upload ke: raw/rdbms/productsrdbms.csv (12 baris)
# 🚀 Berhasil upload ke: raw/rdbms/ordersrdbms.csv (24 baris)
#
# --- Processing File Data ---
# 🚀 Berhasil upload ke: raw/csv/products.csv (12 baris)
# 🚀 Berhasil upload ke: raw/xlsx/orders.csv (24 baris)
#
# 🎉 Semua data berhasil di-ingestion ke MinIO!
